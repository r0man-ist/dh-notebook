# %% [markdown]
# # Dinglehopper

# %% [markdown]
# Installieren von dinglehopper

# %%
# !pip install dinglehopper

# %% [markdown]
# ### Vergleichsdaten in Notebookverzeichnis hochladen

# %% [markdown]
# ![image.png](attachment:754ae552-a31d-4873-97a6-3ed311108df8.png)

# %% [markdown]
# ### Dinglehopper starten

# %%
# !dinglehopper a.xml b.xml

# %% [markdown]
# ### Ergebnisse ansehen

# %% [markdown]
# ![image.png](attachment:0763d966-63e2-4a5d-8a92-e52bea698e54.png)
#
# ![image.png](attachment:f186096a-9633-4f1d-9de9-d8261982e327.png)
#
# report.json
# bzw.
# report.html
